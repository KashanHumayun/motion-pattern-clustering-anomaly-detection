# %% [markdown]
# # Motion Pattern Demo Walkthrough
#
# This notebook reads the unsupervised demo outputs, reviews cluster quality, and inspects flagged anomalies.

# %%
from pathlib import Path
import json
import pandas as pd

ROOT = Path.cwd().resolve().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
REPORTS = ROOT / 'reports' / 'demo'
MODELS = ROOT / 'models' / 'demo'

summary = json.loads((REPORTS / 'summary.json').read_text())
analysis = pd.read_csv(REPORTS / 'motion_analysis.csv')
summary['anomaly_detection']['anomaly_count'], MODELS

# %%
pd.DataFrame([
    ['silhouette_score', summary['kmeans']['silhouette_score']],
    ['dbscan_clusters_found', summary['dbscan']['clusters_found']],
    ['dbscan_noise_points', summary['dbscan']['noise_points']],
    ['anomaly_count', summary['anomaly_detection']['anomaly_count']],
], columns=['metric', 'value'])

# %%
analysis.sort_values('anomaly_score', ascending=False)[['sample_id', 'strain_band', 'anomaly_score', 'review_note']].head(10)
